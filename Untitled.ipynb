# %%
import pandas as pd

# %%
df = pd.read_csv('mly375.csv')

# %%
print(df)
df.info()
# Out:
#                   Station Name: OAK PARK         Unnamed: 1 Unnamed: 2  \
# 0                  Station Height: 62 M                 NaN        NaN
# 1                      Latitude:52.861    Longitude: -6.915        NaN
# 2                         year:  -  Year                NaN        NaN
# 3                        month: -  Month                NaN        NaN
# 4    rain:  -  Precipitation Amount (mm)                NaN        NaN
# ..                                   ...                ...        ...
# 269                                 2025                  5       12.8
# 270                                 2025                  6       15.3
# 271                                 2025                  7       17.3
# 272                                 2025                  8       16.9
# 273                                 2025                  9       12.9
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...
