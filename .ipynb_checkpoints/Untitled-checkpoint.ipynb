# %%
Ryan Dunne
C00263405

# %% [markdown]
# Is climate change evident in Carlow?
# Oak Park Weather Station 2004 - 2025
#
# KEYS:
# year:  -  Year
# month: -  Month
# rain:  -  Precipitation Amount (mm)
# meant: -  Mean Air Temperature (C)
# "maxtp: -  Maximum Air Temperature (C)	  "
# "mintp: -  Minimum  Air Temperature (C)	"
# mnmax: -  Mean Maximum Temperature (C)
# mnmin: -  Mean Minimum Temperature (C)
# gmin:  -  Grass Minimum Temperature (C)
# wdsp:  -  Mean Wind Speed (knot)
# mxgt:  -  Highest Gust (knot)

# %%
import pandas as pd

# %%
df = pd.read_csv('mly375.csv', skiprows=4)

# %%
print(df)
df.columns
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain  gmin  wdsp  maxgt
# 0    2004      1    5.4   12.3   -5.9    8.5    2.4   82.7 -10.3   8.4     50
# 1    2004      3    6.6   15.9   -5.1   10.6    2.5   70.9  -9.7   9.0     57
# 2    2004      4    8.6   17.1    0.6   12.6    4.6   59.2  -3.6   8.4     43
# 3    2004      5   11.2   20.9    1.3   16.2    6.3   34.3  -3.0   6.2     39
# 4    2004      8   16.0   25.4    5.0   20.5   11.6  129.1   1.8   6.5     30
# ..    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...    ...
# 244  2025      5   12.8   22.6    0.1   18.8    6.7   31.7  -4.3   5.9     36
# 245  2025      6   15.3   26.0    5.1   19.8   10.9   62.7   1.0   7.7     36
# 246  2025      7   17.3   30.2    8.1   21.6   12.9   59.8   3.0   6.4     38
# 247  2025      8   16.9   28.0    8.1   21.6   12.3   37.5   3.6   7.0     37
# 248  2025      9   12.9   20.9    0.9   17.3    8.5   87.5  -2.6   7.3     40
#
# [249 rows x 11 columns]
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

rain = df['rain'].to_numpy()
years = df['year'].to_numpy()
meanTemp = df['meant'].to_numpy()

plt.scatter(rain, meanTemp)
plt.ylabel("Mean Temp Celsius")
plt.xlabel("Rainfall mm")
plt.title("Mean Temperature vs Rainfall")
# Out:
# Text(0.5, 1.0, 'Mean Temperature vs Rainfall')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(years[:, np.newaxis], meanTemp)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(years,meanTemp)
plt.plot(xfit, yfit);

# %%
annualMeanTemp = df.groupby("year")["meant"].mean().reset_index()
print(annualMeanTemp)
# Out:
#     year      meant
# 0   2004   8.987500
# 1   2005   9.688889
# 2   2006   9.325000
# 3   2007  10.441667
# 4   2008   9.616667
# 5   2009   9.633333
# 6   2010   8.633333
# 7   2011  10.133333
# 8   2012   9.700000
# 9   2013   9.916667
# 10  2014  10.383333
# 11  2015   9.783333
# 12  2016  10.041667
# 13  2017  10.727273
# 14  2018  10.400000
# 15  2019  10.158333
# 16  2020  10.258333
# 17  2021  10.366667
# 18  2022  10.633333
# 19  2023  11.141667
# 20  2024  10.541667
# 21  2025  11.644444

# %%
plt.scatter(annualMeanTemp["year"], annualMeanTemp["meant"], color='tab:red', s=80)

plt.plot(annualMeanTemp["year"], annualMeanTemp["meant"], color='tab:red')


plt.xlabel("Year")
plt.ylabel("Mean Temperature Celsius")
plt.title("Yearly Mean Temperatures")
plt.show()
